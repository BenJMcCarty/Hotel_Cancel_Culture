# %% [markdown]
# # Forecasting with Sktime

# %%
import matplotlib.pyplot as plt
import pandas as pd


from sktime.forecasting.arima import AutoARIMA
from sktime.forecasting.compose import TransformedTargetForecaster
from sktime.forecasting.model_selection import temporal_train_test_split

from sktime.performance_metrics.forecasting import mean_absolute_percentage_error

from sktime.transformations.series.boxcox import BoxCoxTransformer
from sktime.transformations.series.detrend import ConditionalDeseasonalizer, Deseasonalizer, Detrender

# %%
data = pd.read_feather('../../data/3.3_data_exploded.feather')
data
# Out:
#            ADR ReservationStatus  Stay Date
# 164       0.00         Check-Out 2015-07-01
# 163       4.00         Check-Out 2015-07-01
# 135      55.68         Check-Out 2015-07-01
# 227      62.00         Check-Out 2015-07-01
# 154      62.50         Check-Out 2015-07-01
# ...        ...               ...        ...
# 409000  153.57         Check-Out 2017-09-11
# 409699   99.06         Check-Out 2017-09-12
# 409822  112.80         Check-Out 2017-09-12
# 409700   99.06         Check-Out 2017-09-13
# 409823  112.80         Check-Out 2017-09-13
#
# [409257 rows x 3 columns]

# %%
data['ReservationStatus'].value_counts()
# Out:
# ReservationStatus
# Check-Out    255040
# Canceled     149740
# No-Show        4477
# Name: count, dtype: int64

# %%
co_filter = data['ReservationStatus'] == 'Check-Out'
data = data[co_filter].drop(columns='ReservationStatus')
data
# Out:
#            ADR  Stay Date
# 164       0.00 2015-07-01
# 163       4.00 2015-07-01
# 135      55.68 2015-07-01
# 227      62.00 2015-07-01
# 154      62.50 2015-07-01
# ...        ...        ...
# 409000  153.57 2017-09-11
# 409699   99.06 2017-09-12
# 409822  112.80 2017-09-12
# 409700   99.06 2017-09-13
# 409823  112.80 2017-09-13
#
# [255040 rows x 2 columns]

# %%
data.dtypes
# Out:
# ADR                 float64
# Stay Date    datetime64[ns]
# dtype: object

# %%
data = (data.sort_values(by = 'Stay Date')
        .set_index('Stay Date'))
data
# Out:
#                ADR
# Stay Date
# 2015-07-01    0.00
# 2015-07-01  101.50
# 2015-07-01  101.50
# 2015-07-01  101.50
# 2015-07-01  101.50
# ...            ...
# 2017-09-11  153.57
# 2017-09-12   99.06
# 2017-09-12  112.80
# 2017-09-13   99.06
# 2017-09-13  112.80
#
# [255040 rows x 1 columns]

# %%
y = (data['ADR']
          .resample('ME')
          .median()
          .rolling(window=3)
          .median()
          .dropna()
          .to_frame())
y
# Out:
#                ADR
# Stay Date
# 2015-09-30  112.00
# 2015-10-31   90.00
# 2015-11-30   75.00
# 2015-12-31   65.00
# 2016-01-31   65.00
# 2016-02-29   66.29
# 2016-03-31   66.40
# 2016-04-30   72.00
# 2016-05-31   82.45
# 2016-06-30   89.25
# 2016-07-31   95.00
# 2016-08-31  115.00
# 2016-09-30  115.00
# 2016-10-31  105.64
# 2016-11-30   86.90
# 2016-12-31   79.00
# 2017-01-31   75.00
# 2017-02-28   75.00
# 2017-03-31   74.80
# 2017-04-30   75.00
# 2017-05-31  101.25
# 2017-06-30  108.00
# 2017-07-31  117.45
# 2017-08-31  132.85
# 2017-09-30  134.58

# %%
y_train, y_test = temporal_train_test_split(y, test_size=90)

# %%
# Define the pipeline
forecaster = TransformedTargetForecaster(steps=[
    ("boxcox", BoxCoxTransformer()),
    # ("deseasonalizer", Deseasonalizer(sp=12)),
    # ('deseasonalizer', ConditionalDeseasonalizer(sp=3)),
    ('detrender', Detrender()),
    ("forecaster", AutoARIMA())
])

forecaster.fit(y_train)

fh = list(range(1, len(y_test) + 1))  # Forecast horizon
y_pred = forecaster.predict(fh)
# Out:
# ---------------------------------------------------------------------------
# BracketError                              Traceback (most recent call last)
# Cell In[9], line 10
#       1 # Define the pipeline
#       2 forecaster = TransformedTargetForecaster(steps=[
#       3     ("boxcox", BoxCoxTransformer()),
#       4     # ("deseasonalizer", Deseasonalizer(sp=12)),
#    (...)
#       7     ("forecaster", AutoARIMA())
#       8 ])
# ---> 10 forecaster.fit(y_train)
#      12 fh = list(range(1, len(y_test) + 1))  # Forecast horizon
#      13 y_pred = forecaster.predict(fh)
#
# File c:\Users\Ben\miniforge3\envs\ds-env\Lib\site-packages\sktime\forecasting\base\_base.py:391, in BaseForecaster.fit(self, y, X, fh)
#     389 # we call the ordinary _fit if no looping/vectorization needed
#     390 if not vectorization_needed:
# --> 391     self._fit(y=y_inner, X=X_inner, fh=fh)
#     392 else:
#     393     # otherwise we call the vectorized version of fit
#     394     self._vectorize("fit", y=y_inner, X=X_inner, fh=fh)
#
# File c:\Users\Ben\miniforge3\envs\ds-env\Lib\site-packages\sktime\forecasting\compose\_pipeline.py:1027, in TransformedTargetForecaster._fit(self, y, X, fh)
#    1025 yt = y
#    1026 for _, t in self.transformers_pre_:
# -> 1027     yt = t.fit_transform(X=yt, y=X)
#    1029 # fit forecaster
#    1030 f = self.forecaster_
#
# File c:\Users\Ben\miniforge3\envs\ds-env\Lib\site-packages\sktime\transformations\base.py:707, in BaseTransformer.fit_transform(self, X, y)
#     633 """Fit to data, then transform it.
#     634
#     635 Fits the transformer to X and y and returns a transformed version of X.
#    (...)
#     703         Example: i-th instance of the output is the i-th window running over `X`
#     704 """
#     705 # Non-optimized default implementation; override when a better
#     706 # method is possible for a given algorithm.
# --> 707 return self.fit(X, y).transform(X, y)
#
# File c:\Users\Ben\miniforge3\envs\ds-env\Lib\site-packages\sktime\transformations\base.py:508, in BaseTransformer.fit(self, X, y)
#     506 # we call the ordinary _fit if no looping/vectorization needed
#     507 if not vectorization_needed:
# --> 508     self._fit(X=X_inner, y=y_inner)
#     509 else:
#     510     # otherwise we call the vectorized version of fit
#     511     self._vectorize("fit", X=X_inner, y=y_inner)
#
# File c:\Users\Ben\miniforge3\envs\ds-env\Lib\site-packages\sktime\transformations\series\boxcox.py:236, in BoxCoxTransformer._fit(self, X, y)
#     233     X = np.abs(X)
#     235 if self.method in ["pearsonr", "mle", "all"]:
# --> 236     self.lambda_ = _box_norm(X, bounds, method)
#     237 elif method == "guerrero":
#     238     self.lambda_ = _guerrero(X, sp, bounds)
#
# File c:\Users\Ben\miniforge3\envs\ds-env\Lib\site-packages\sktime\transformations\series\boxcox.py:65, in _box_norm(X, bounds, method)
#      62     else:
#      63         args = {"brack": bounds}
# ---> 65 return box_norm(X, method=method, **args)
#
# File c:\Users\Ben\miniforge3\envs\ds-env\Lib\site-packages\scipy\stats\_morestats.py:1343, in boxcox_normmax(x, brack, method, optimizer, ymax)
#    1339     raise ValueError(f"Method {method} not recognized.")
#    1341 optimfunc = methods[method]
# -> 1343 res = optimfunc(x)
#    1345 if res is None:
#    1346     message = ("The `optimizer` argument of `boxcox_normmax` must return "
#    1347                "an object containing the optimal `lmbda` in attribute `x`.")
#
# File c:\Users\Ben\miniforge3\envs\ds-env\Lib\site-packages\scipy\stats\_morestats.py:1327, in boxcox_normmax.<locals>._mle(x)
#    1323 def _eval_mle(lmb, data):
#    1324     # function to minimize
#    1325     return -boxcox_llf(lmb, data)
# -> 1327 return _optimizer(_eval_mle, args=(x,))
#
# File c:\Users\Ben\miniforge3\envs\ds-env\Lib\site-packages\scipy\stats\_morestats.py:1289, in boxcox_normmax.<locals>._optimizer(func, args)
#    1288 def _optimizer(func, args):
# -> 1289     return optimize.brent(func, args=args, brack=brack)
#
# File c:\Users\Ben\miniforge3\envs\ds-env\Lib\site-packages\scipy\optimize\_optimize.py:2625, in brent(func, args, brack, tol, full_output, maxiter)
#    2553 """
#    2554 Given a function of one variable and a possible bracket, return
#    2555 a local minimizer of the function isolated to a fractional precision
#    (...)
#    2621
#    2622 """
#    2623 options = {'xtol': tol,
#    2624            'maxiter': maxiter}
# -> 2625 res = _minimize_scalar_brent(func, brack, args, **options)
#    2626 if full_output:
#    2627     return res['x'], res['fun'], res['nit'], res['nfev']
#
# File c:\Users\Ben\miniforge3\envs\ds-env\Lib\site-packages\scipy\optimize\_optimize.py:2662, in _minimize_scalar_brent(func, brack, args, xtol, maxiter, disp, **unknown_options)
#    2659 brent = Brent(func=func, args=args, tol=tol,
#    2660               full_output=True, maxiter=maxiter, disp=disp)
#    2661 brent.set_bracket(brack)
# -> 2662 brent.optimize()
#    2663 x, fval, nit, nfev = brent.get_result(full_output=True)
#    2665 success = nit < maxiter and not (np.isnan(x) or np.isnan(fval))
#
# File c:\Users\Ben\miniforge3\envs\ds-env\Lib\site-packages\scipy\optimize\_optimize.py:2432, in Brent.optimize(self)
#    2429 def optimize(self):
#    2430     # set up for optimization
#    2431     func = self.func
# -> 2432     xa, xb, xc, fa, fb, fc, funcalls = self.get_bracket_info()
#    2433     _mintol = self._mintol
#    2434     _cg = self._cg
#
# File c:\Users\Ben\miniforge3\envs\ds-env\Lib\site-packages\scipy\optimize\_optimize.py:2401, in Brent.get_bracket_info(self)
#    2399     xa, xb, xc, fa, fb, fc, funcalls = bracket(func, args=args)
#    2400 elif len(brack) == 2:
# -> 2401     xa, xb, xc, fa, fb, fc, funcalls = bracket(func, xa=brack[0],
#    2402                                                xb=brack[1], args=args)
#    2403 elif len(brack) == 3:
#    2404     xa, xb, xc = brack
#
# File c:\Users\Ben\miniforge3\envs\ds-env\Lib\site-packages\scipy\optimize\_optimize.py:3031, in bracket(func, xa, xb, args, grow_limit, maxiter)
#    3029     e = BracketError(msg)
#    3030     e.data = (xa, xb, xc, fa, fb, fc, funcalls)
# -> 3031     raise e
#    3033 return xa, xb, xc, fa, fb, fc, funcalls
#
# BracketError: The algorithm terminated without finding a valid bracket. Consider trying different initial points.

# %%
mape = mean_absolute_percentage_error(y_test, y_pred)
print(f'MAPE: {mape * 100:.2f}%')

plt.figure(figsize=(10, 6))
plt.plot(y_train, label='Train')
plt.plot(y_test, label='Test')
plt.plot(y_pred, label='Predictions')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 mape = mean_absolute_percentage_error(y_test, y_pred)
#       2 print(f'MAPE: {mape * 100:.2f}%')
#       4 plt.figure(figsize=(10, 6))
#
# File c:\Users\Ben\miniforge3\envs\ds-env\Lib\site-packages\sktime\performance_metrics\forecasting\_functions.py:1549, in mean_absolute_percentage_error(y_true, y_pred, horizon_weight, multioutput, symmetric, **kwargs)
#    1455 def mean_absolute_percentage_error(
#    1456     y_true,
#    1457     y_pred,
#    (...)
#    1461     **kwargs,
#    1462 ):
#    1463     """Mean absolute percentage error (MAPE) or symmetric version.
#    1464
#    1465     If ``symmetric`` is False then calculates MAPE and if ``symmetric`` is True
#    (...)
#    1547     0.5668686868686869
#    1548     """
# -> 1549     _, y_true, y_pred, multioutput = _check_reg_targets(y_true, y_pred, multioutput)
#    1550     if horizon_weight is not None:
#    1551         check_consistent_length(y_true, horizon_weight)
#
# File c:\Users\Ben\miniforge3\envs\ds-env\Lib\site-packages\sklearn\metrics\_regression.py:111, in _check_reg_targets(y_true, y_pred, multioutput, dtype, xp)
#      76 """Check that y_true and y_pred belong to the same regression task.
#      77
#      78 Parameters
#    (...)
#     107     correct keyword.
#     108 """
#     109 xp, _ = get_namespace(y_true, y_pred, multioutput, xp=xp)
# --> 111 check_consistent_length(y_true, y_pred)
#     112 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     113 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File c:\Users\Ben\miniforge3\envs\ds-env\Lib\site-packages\sklearn\utils\validation.py:460, in check_consistent_length(*arrays)
#     458 uniques = np.unique(lengths)
#     459 if len(uniques) > 1:
# --> 460     raise ValueError(
#     461         "Found input variables with inconsistent numbers of samples: %r"
#     462         % [int(l) for l in lengths]
#     463     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [8, 90]
