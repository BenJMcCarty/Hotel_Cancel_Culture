# %% [markdown]
# # Converting Data Source Files to Database

# %%
import duckdb
import pandas as pd
import uuid

# %% [markdown]
# # Load Data

# %%
h1 = pd.read_csv('../../data/source/H1.csv')
h2 = pd.read_csv('../../data/source/H2.csv')

# %%
h1.head()
# Out:
#    IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0           0       342             2015             July
# 1           0       737             2015             July
# 2           0         7             2015             July
# 3           0        13             2015             July
# 4           0        14             2015             July
#
#    ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                     27                      1                     0
# 1                     27                      1                     0
# 2                     27                      1                     0
# 3                     27                      1                     0
# 4                     27                      1                     0
#
#    StaysInWeekNights  Adults  Children  ...      DepositType        Agent  \
# 0                  0       2         0  ...  No Deposit              NULL
# 1                  0       2         0  ...  No Deposit              NULL
# 2                  1       1         0  ...  No Deposit              NULL
# 3                  1       1         0  ...  No Deposit               304
# 4                  2       2         0  ...  No Deposit               240
#
#        Company DaysInWaitingList CustomerType   ADR  RequiredCarParkingSpaces  \
# 0         NULL                 0    Transient   0.0                         0
# 1         NULL                 0    Transient   0.0                         0
# 2         NULL                 0    Transient  75.0                         0
# 3         NULL                 0    Transient  75.0                         0
# 4         NULL                 0    Transient  98.0                         0
#
#    TotalOfSpecialRequests ReservationStatus ReservationStatusDate
# 0                       0         Check-Out            2015-07-01
# 1                       0         Check-Out            2015-07-01
# 2                       0         Check-Out            2015-07-02
# 3                       0         Check-Out            2015-07-02
# 4                       1         Check-Out            2015-07-03
#
# [5 rows x 31 columns]

# %%
h1['HotelName'] = 'H1'
h2['HotelName'] = 'H2'

# %%
data = pd.concat([h1, h2], axis = 0)
data.head()
# Out:
#    IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0           0       342             2015             July
# 1           0       737             2015             July
# 2           0         7             2015             July
# 3           0        13             2015             July
# 4           0        14             2015             July
#
#    ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                     27                      1                     0
# 1                     27                      1                     0
# 2                     27                      1                     0
# 3                     27                      1                     0
# 4                     27                      1                     0
#
#    StaysInWeekNights  Adults  Children  ...        Agent      Company  \
# 0                  0       2       0.0  ...         NULL         NULL
# 1                  0       2       0.0  ...         NULL         NULL
# 2                  1       1       0.0  ...         NULL         NULL
# 3                  1       1       0.0  ...          304         NULL
# 4                  2       2       0.0  ...          240         NULL
#
#   DaysInWaitingList CustomerType   ADR  RequiredCarParkingSpaces  \
# 0                 0    Transient   0.0                         0
# 1                 0    Transient   0.0                         0
# 2                 0    Transient  75.0                         0
# 3                 0    Transient  75.0                         0
# 4                 0    Transient  98.0                         0
#
#    TotalOfSpecialRequests  ReservationStatus ReservationStatusDate HotelName
# 0                       0          Check-Out            2015-07-01        H1
# 1                       0          Check-Out            2015-07-01        H1
# 2                       0          Check-Out            2015-07-02        H1
# 3                       0          Check-Out            2015-07-02        H1
# 4                       1          Check-Out            2015-07-03        H1
#
# [5 rows x 32 columns]

# %% [markdown]
# # Add UUIDs to Reservations

# %%
data
# Out:
#        IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0               0       342             2015             July
# 1               0       737             2015             July
# 2               0         7             2015             July
# 3               0        13             2015             July
# 4               0        14             2015             July
# ...           ...       ...              ...              ...
# 79325           0        23             2017           August
# 79326           0       102             2017           August
# 79327           0        34             2017           August
# 79328           0       109             2017           August
# 79329           0       205             2017           August
#
#        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                         27                      1                     0
# 1                         27                      1                     0
# 2                         27                      1                     0
# 3                         27                      1                     0
# 4                         27                      1                     0
# ...                      ...                    ...                   ...
# 79325                     35                     30                     2
# 79326                     35                     31                     2
# 79327                     35                     31                     2
# 79328                     35                     31                     2
# 79329                     35                     29                     2
#
#        StaysInWeekNights  Adults  Children  ...        Agent      Company  \
# 0                      0       2       0.0  ...         NULL         NULL
# 1                      0       2       0.0  ...         NULL         NULL
# 2                      1       1       0.0  ...         NULL         NULL
# 3                      1       1       0.0  ...          304         NULL
# 4                      2       2       0.0  ...          240         NULL
# ...                  ...     ...       ...  ...          ...          ...
# 79325                  5       2       0.0  ...          394         NULL
# 79326                  5       3       0.0  ...            9         NULL
# 79327                  5       2       0.0  ...            9         NULL
# 79328                  5       2       0.0  ...           89         NULL
# 79329                  7       2       0.0  ...            9         NULL
#
#       DaysInWaitingList CustomerType     ADR  RequiredCarParkingSpaces  \
# 0                     0    Transient    0.00                         0
# 1                     0    Transient    0.00                         0
# 2                     0    Transient   75.00                         0
# 3                     0    Transient   75.00                         0
# 4                     0    Transient   98.00                         0
# ...                 ...          ...     ...                       ...
# 79325                 0    Transient   96.14                         0
# 79326                 0    Transient  225.43                         0
# 79327                 0    Transient  157.71                         0
# 79328                 0    Transient  104.40                         0
# 79329                 0    Transient  151.20                         0
#
#        TotalOfSpecialRequests  ReservationStatus ReservationStatusDate  \
# 0                           0          Check-Out            2015-07-01
# 1                           0          Check-Out            2015-07-01
# 2                           0          Check-Out            2015-07-02
# 3                           0          Check-Out            2015-07-02
# 4                           1          Check-Out            2015-07-03
# ...                       ...                ...                   ...
# 79325                       0          Check-Out            2017-09-06
# 79326                       2          Check-Out            2017-09-07
# 79327                       4          Check-Out            2017-09-07
# 79328                       0          Check-Out            2017-09-07
# 79329                       2          Check-Out            2017-09-07
#
#       HotelName
# 0            H1
# 1            H1
# 2            H1
# 3            H1
# 4            H1
# ...         ...
# 79325        H2
# 79326        H2
# 79327        H2
# 79328        H2
# 79329        H2
#
# [119390 rows x 32 columns]

# %%
# Generate UUIDs for each row in the dataframe
data['UUID'] = [uuid.uuid4() for _ in range(len(data))]
data['UUID'].head()
# Out:
# 0    f7add1ce-8fdb-4351-a20a-3c5cc66fc87d
# 1    990a199b-069b-4e78-9036-fe8ea73a1f3e
# 2    91d6303b-16f8-41b2-a195-f6bcb9ee605a
# 3    df309bdf-5fd8-4789-9b52-01de65e43a22
# 4    007c51b0-4d0e-40ca-b550-34c93d2ca9a7
# Name: UUID, dtype: object

# %%
data
# Out:
#        IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0               0       342             2015             July
# 1               0       737             2015             July
# 2               0         7             2015             July
# 3               0        13             2015             July
# 4               0        14             2015             July
# ...           ...       ...              ...              ...
# 79325           0        23             2017           August
# 79326           0       102             2017           August
# 79327           0        34             2017           August
# 79328           0       109             2017           August
# 79329           0       205             2017           August
#
#        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                         27                      1                     0
# 1                         27                      1                     0
# 2                         27                      1                     0
# 3                         27                      1                     0
# 4                         27                      1                     0
# ...                      ...                    ...                   ...
# 79325                     35                     30                     2
# 79326                     35                     31                     2
# 79327                     35                     31                     2
# 79328                     35                     31                     2
# 79329                     35                     29                     2
#
#        StaysInWeekNights  Adults  Children  ...      Company  \
# 0                      0       2       0.0  ...         NULL
# 1                      0       2       0.0  ...         NULL
# 2                      1       1       0.0  ...         NULL
# 3                      1       1       0.0  ...         NULL
# 4                      2       2       0.0  ...         NULL
# ...                  ...     ...       ...  ...          ...
# 79325                  5       2       0.0  ...         NULL
# 79326                  5       3       0.0  ...         NULL
# 79327                  5       2       0.0  ...         NULL
# 79328                  5       2       0.0  ...         NULL
# 79329                  7       2       0.0  ...         NULL
#
#       DaysInWaitingList CustomerType     ADR RequiredCarParkingSpaces  \
# 0                     0    Transient    0.00                        0
# 1                     0    Transient    0.00                        0
# 2                     0    Transient   75.00                        0
# 3                     0    Transient   75.00                        0
# 4                     0    Transient   98.00                        0
# ...                 ...          ...     ...                      ...
# 79325                 0    Transient   96.14                        0
# 79326                 0    Transient  225.43                        0
# 79327                 0    Transient  157.71                        0
# 79328                 0    Transient  104.40                        0
# 79329                 0    Transient  151.20                        0
#
#        TotalOfSpecialRequests  ReservationStatus  ReservationStatusDate  \
# 0                           0          Check-Out             2015-07-01
# 1                           0          Check-Out             2015-07-01
# 2                           0          Check-Out             2015-07-02
# 3                           0          Check-Out             2015-07-02
# 4                           1          Check-Out             2015-07-03
# ...                       ...                ...                    ...
# 79325                       0          Check-Out             2017-09-06
# 79326                       2          Check-Out             2017-09-07
# 79327                       4          Check-Out             2017-09-07
# 79328                       0          Check-Out             2017-09-07
# 79329                       2          Check-Out             2017-09-07
#
#       HotelName                                  UUID
# 0            H1  f7add1ce-8fdb-4351-a20a-3c5cc66fc87d
# 1            H1  990a199b-069b-4e78-9036-fe8ea73a1f3e
# 2            H1  91d6303b-16f8-41b2-a195-f6bcb9ee605a
# 3            H1  df309bdf-5fd8-4789-9b52-01de65e43a22
# 4            H1  007c51b0-4d0e-40ca-b550-34c93d2ca9a7
# ...         ...                                   ...
# 79325        H2  df4a8193-4b75-499a-980c-e965c9d0e078
# 79326        H2  3151aa1f-530a-4650-b37e-9f1cbace4b9f
# 79327        H2  0425bc44-e7d7-4c4a-988a-4596901c6028
# 79328        H2  70b6aa09-9785-4205-8ee6-d51485789de1
# 79329        H2  079c7b8b-7834-4d55-a5a4-d2ac636f6151
#
# [119390 rows x 33 columns]

# %% [markdown]
# # Create Database and Add Data

# %%
## Create connection to database and add data; create either if nonexistent
with duckdb.connect(database='../../data/reservation_data.duckdb', read_only=False) as conn:
    conn.execute("CREATE TABLE IF NOT EXISTS data AS SELECT * FROM data")

with duckdb.connect(database='reservation_data.duckdb', read_only=False) as conn:
    result = conn.execute("SELECT * FROM data LIMIT 100").fetchdf()
    display(result)
# Out:
#     IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0          0.0     342.0           2015.0             July
# 1          0.0     737.0           2015.0             July
# 2          0.0       7.0           2015.0             July
# 3          0.0      13.0           2015.0             July
# 4          0.0      14.0           2015.0             July
# ..         ...       ...              ...              ...
# 95         1.0      72.0           2015.0             July
# 96         1.0      63.0           2015.0             July
# 97         0.0      63.0           2015.0             July
# 98         0.0     101.0           2015.0             July
# 99         0.0     102.0           2015.0             July
#
#     ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                    27.0                    1.0                   0.0
# 1                    27.0                    1.0                   0.0
# 2                    27.0                    1.0                   0.0
# 3                    27.0                    1.0                   0.0
# 4                    27.0                    1.0                   0.0
# ..                    ...                    ...                   ...
# 95                   27.0                    3.0                   0.0
# 96                   27.0                    3.0                   2.0
# 97                   27.0                    3.0                   2.0
# 98                   27.0                    3.0                   2.0
# 99                   27.0                    3.0                   2.0
#
#     StaysInWeekNights  Adults  Children  ...      Agent_1    Company_1  \
# 0                 0.0     2.0       0.0  ...            6         NULL
# 1                 0.0     2.0       0.0  ...            9         NULL
# 2                 1.0     1.0       0.0  ...            9         NULL
# 3                 1.0     1.0       0.0  ...            9         NULL
# 4                 2.0     2.0       0.0  ...            9         NULL
# ..                ...     ...       ...  ...          ...          ...
# 95                2.0     2.0       0.0  ...           17         NULL
# 96                5.0     2.0       0.0  ...           17         NULL
# 97                5.0     3.0       0.0  ...           17         NULL
# 98                5.0     2.0       1.0  ...           17         NULL
# 99                5.0     2.0       0.0  ...           17         NULL
#
#    DaysInWaitingList_1   CustomerType_1 ADR_1  RequiredCarParkingSpaces_1  \
# 0                    0        Transient   0.0                           0
# 1                    0        Transient  76.5                           0
# 2                    0        Transient  68.0                           0
# 3                    0        Transient  76.5                           0
# 4                    0        Transient  76.5                           0
# ..                 ...              ...   ...                         ...
# 95                   0  Transient-Party  72.5                           0
# 96                   0  Transient-Party  94.5                           0
# 97                   0  Transient-Party  94.5                           0
# 98                   0  Transient-Party  94.5                           0
# 99                   0  Transient-Party  94.5                           0
#
#     TotalOfSpecialRequests_1  ReservationStatus_1 ReservationStatusDate_1  \
# 0                          0            Check-Out              2015-07-03
# 1                          1             Canceled              2015-07-01
# 2                          1             Canceled              2015-04-30
# 3                          2             Canceled              2015-06-23
# 4                          1             Canceled              2015-04-02
# ..                       ...                  ...                     ...
# 95                         0            Check-Out              2015-07-14
# 96                         0            Check-Out              2015-07-14
# 97                         0             Canceled              2015-06-23
# 98                         0             Canceled              2015-06-23
# 99                         0            Check-Out              2015-07-14
#
#    HotelName_1
# 0           H2
# 1           H2
# 2           H2
# 3           H2
# 4           H2
# ..         ...
# 95          H2
# 96          H2
# 97          H2
# 98          H2
# 99          H2
#
# [100 rows x 64 columns]

# %%
conn.close()
