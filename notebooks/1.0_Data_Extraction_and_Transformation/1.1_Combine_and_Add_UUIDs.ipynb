# %% [markdown]
# # Adding UUIDs to Reservations

# %%
## Import pandas to handle data and `uuid` to create unique reservation IDs
import pandas as pd
import uuid

# %% [markdown]
# # Load and Concatenate Data

# %%
## Load datasets and add column to indicate hotel type/location

df_h1 = pd.read_csv('../../data/source/H1.csv')
df_h1['HotelNumber'] = 'H1'
df_h1['HotelNumber'] = df_h1['HotelNumber'].astype('category')

df_h2 = pd.read_csv('../../data/source/H2.csv')
df_h2['HotelNumber'] = 'H2'
df_h2['HotelNumber'] = df_h2['HotelNumber'].astype('category')

# %%
data = pd.concat([df_h1,df_h2],axis = 0).reset_index(drop = True)
data
# Out:
#         IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0                0       342             2015             July
# 1                0       737             2015             July
# 2                0         7             2015             July
# 3                0        13             2015             July
# 4                0        14             2015             July
# ...            ...       ...              ...              ...
# 119385           0        23             2017           August
# 119386           0       102             2017           August
# 119387           0        34             2017           August
# 119388           0       109             2017           August
# 119389           0       205             2017           August
#
#         ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                          27                      1                     0
# 1                          27                      1                     0
# 2                          27                      1                     0
# 3                          27                      1                     0
# 4                          27                      1                     0
# ...                       ...                    ...                   ...
# 119385                     35                     30                     2
# 119386                     35                     31                     2
# 119387                     35                     31                     2
# 119388                     35                     31                     2
# 119389                     35                     29                     2
#
#         StaysInWeekNights  Adults  Children  ...        Agent      Company  \
# 0                       0       2       0.0  ...         NULL         NULL
# 1                       0       2       0.0  ...         NULL         NULL
# 2                       1       1       0.0  ...         NULL         NULL
# 3                       1       1       0.0  ...          304         NULL
# 4                       2       2       0.0  ...          240         NULL
# ...                   ...     ...       ...  ...          ...          ...
# 119385                  5       2       0.0  ...          394         NULL
# 119386                  5       3       0.0  ...            9         NULL
# 119387                  5       2       0.0  ...            9         NULL
# 119388                  5       2       0.0  ...           89         NULL
# 119389                  7       2       0.0  ...            9         NULL
#
#        DaysInWaitingList CustomerType     ADR  RequiredCarParkingSpaces  \
# 0                      0    Transient    0.00                         0
# 1                      0    Transient    0.00                         0
# 2                      0    Transient   75.00                         0
# 3                      0    Transient   75.00                         0
# 4                      0    Transient   98.00                         0
# ...                  ...          ...     ...                       ...
# 119385                 0    Transient   96.14                         0
# 119386                 0    Transient  225.43                         0
# 119387                 0    Transient  157.71                         0
# 119388                 0    Transient  104.40                         0
# 119389                 0    Transient  151.20                         0
#
#         TotalOfSpecialRequests  ReservationStatus ReservationStatusDate  \
# 0                            0          Check-Out            2015-07-01
# 1                            0          Check-Out            2015-07-01
# 2                            0          Check-Out            2015-07-02
# 3                            0          Check-Out            2015-07-02
# 4                            1          Check-Out            2015-07-03
# ...                        ...                ...                   ...
# 119385                       0          Check-Out            2017-09-06
# 119386                       2          Check-Out            2017-09-07
# 119387                       4          Check-Out            2017-09-07
# 119388                       0          Check-Out            2017-09-07
# 119389                       2          Check-Out            2017-09-07
#
#        HotelNumber
# 0               H1
# 1               H1
# 2               H1
# 3               H1
# 4               H1
# ...            ...
# 119385          H2
# 119386          H2
# 119387          H2
# 119388          H2
# 119389          H2
#
# [119390 rows x 32 columns]

# %% [markdown]
# # Generate UUIDs and Append to DataFrame

# %%
# Generate UUIDs for each row in the dataframe
data['UUID'] = [uuid.uuid4() for _ in range(len(data))]
data
# Out:
#         IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0                0       342             2015             July
# 1                0       737             2015             July
# 2                0         7             2015             July
# 3                0        13             2015             July
# 4                0        14             2015             July
# ...            ...       ...              ...              ...
# 119385           0        23             2017           August
# 119386           0       102             2017           August
# 119387           0        34             2017           August
# 119388           0       109             2017           August
# 119389           0       205             2017           August
#
#         ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                          27                      1                     0
# 1                          27                      1                     0
# 2                          27                      1                     0
# 3                          27                      1                     0
# 4                          27                      1                     0
# ...                       ...                    ...                   ...
# 119385                     35                     30                     2
# 119386                     35                     31                     2
# 119387                     35                     31                     2
# 119388                     35                     31                     2
# 119389                     35                     29                     2
#
#         StaysInWeekNights  Adults  Children  ...      Company  \
# 0                       0       2       0.0  ...         NULL
# 1                       0       2       0.0  ...         NULL
# 2                       1       1       0.0  ...         NULL
# 3                       1       1       0.0  ...         NULL
# 4                       2       2       0.0  ...         NULL
# ...                   ...     ...       ...  ...          ...
# 119385                  5       2       0.0  ...         NULL
# 119386                  5       3       0.0  ...         NULL
# 119387                  5       2       0.0  ...         NULL
# 119388                  5       2       0.0  ...         NULL
# 119389                  7       2       0.0  ...         NULL
#
#        DaysInWaitingList CustomerType     ADR RequiredCarParkingSpaces  \
# 0                      0    Transient    0.00                        0
# 1                      0    Transient    0.00                        0
# 2                      0    Transient   75.00                        0
# 3                      0    Transient   75.00                        0
# 4                      0    Transient   98.00                        0
# ...                  ...          ...     ...                      ...
# 119385                 0    Transient   96.14                        0
# 119386                 0    Transient  225.43                        0
# 119387                 0    Transient  157.71                        0
# 119388                 0    Transient  104.40                        0
# 119389                 0    Transient  151.20                        0
#
#         TotalOfSpecialRequests  ReservationStatus  ReservationStatusDate  \
# 0                            0          Check-Out             2015-07-01
# 1                            0          Check-Out             2015-07-01
# 2                            0          Check-Out             2015-07-02
# 3                            0          Check-Out             2015-07-02
# 4                            1          Check-Out             2015-07-03
# ...                        ...                ...                    ...
# 119385                       0          Check-Out             2017-09-06
# 119386                       2          Check-Out             2017-09-07
# 119387                       4          Check-Out             2017-09-07
# 119388                       0          Check-Out             2017-09-07
# 119389                       2          Check-Out             2017-09-07
#
#        HotelNumber                                  UUID
# 0               H1  873e7749-dcb5-4c01-b54f-46082557421a
# 1               H1  17c448f2-8715-43d3-a34d-06e0c6ccb502
# 2               H1  ccfd11ba-608d-46bb-a97a-7af0dc59fc7d
# 3               H1  0b80d489-ff99-4533-b2e2-c07747cb9681
# 4               H1  9b03c838-e88c-4682-b491-1f929402c92d
# ...            ...                                   ...
# 119385          H2  6ba8edf2-3269-47dd-a643-1717a82977db
# 119386          H2  1772f97b-c98e-483c-b3ed-4e19741a0c0b
# 119387          H2  1da248f6-1191-4391-9490-066d3bc5d9a8
# 119388          H2  2665afe4-8c01-43b7-a2db-80122963f613
# 119389          H2  55267b08-7625-4461-a922-14093836ba2b
#
# [119390 rows x 33 columns]

# %% [markdown]
# ## Convert UUIDs to String Datatype

# %%
data['UUID'] = data['UUID'].astype(str)
data['UUID']
# Out:
# 0         873e7749-dcb5-4c01-b54f-46082557421a
# 1         17c448f2-8715-43d3-a34d-06e0c6ccb502
# 2         ccfd11ba-608d-46bb-a97a-7af0dc59fc7d
# 3         0b80d489-ff99-4533-b2e2-c07747cb9681
# 4         9b03c838-e88c-4682-b491-1f929402c92d
#                           ...
# 119385    6ba8edf2-3269-47dd-a643-1717a82977db
# 119386    1772f97b-c98e-483c-b3ed-4e19741a0c0b
# 119387    1da248f6-1191-4391-9490-066d3bc5d9a8
# 119388    2665afe4-8c01-43b7-a2db-80122963f613
# 119389    55267b08-7625-4461-a922-14093836ba2b
# Name: UUID, Length: 119390, dtype: object

# %% [markdown]
# ## Set UUIDs as Index
#
# ---
#
# By setting the UUIDs as the dataframe's index, I maintain the unique identifier for each reservation and enable myself to perform joins with other datasets (such as engineered datasets later in the workflow0).
#
# ---

# %%
# data = data.set_index('UUID')
# data

# %% [markdown]
# # Save Results

# %%
data.to_feather('../../data/source/full_data.feather', compression = 'zstd')
