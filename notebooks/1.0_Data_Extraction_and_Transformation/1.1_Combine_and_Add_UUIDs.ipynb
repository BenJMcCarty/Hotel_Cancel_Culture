# %% [markdown]
# # Adding UUIDs to Reservations

# %%
## Import pandas to handle data and `uuid` to create unique reservation IDs
import pandas as pd
import uuid

# %% [markdown]
# # Load and Concatenate Data

# %%
## Load datasets and add column to indicate hotel type/location

df_h1 = pd.read_csv('../../data/source/H1.csv')
df_h1['HotelNumber'] = 'H1'
df_h1['HotelNumber'] = df_h1['HotelNumber'].astype('category')

df_h2 = pd.read_csv('../../data/source/H2.csv')
df_h2['HotelNumber'] = 'H2'
df_h2['HotelNumber'] = df_h2['HotelNumber'].astype('category')

# %%
data = pd.concat([df_h1,df_h2],axis = 0).reset_index(drop = True)
data
# Out:
#         IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0                0       342             2015             July
# 1                0       737             2015             July
# 2                0         7             2015             July
# 3                0        13             2015             July
# 4                0        14             2015             July
# ...            ...       ...              ...              ...
# 119385           0        23             2017           August
# 119386           0       102             2017           August
# 119387           0        34             2017           August
# 119388           0       109             2017           August
# 119389           0       205             2017           August
#
#         ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                          27                      1                     0
# 1                          27                      1                     0
# 2                          27                      1                     0
# 3                          27                      1                     0
# 4                          27                      1                     0
# ...                       ...                    ...                   ...
# 119385                     35                     30                     2
# 119386                     35                     31                     2
# 119387                     35                     31                     2
# 119388                     35                     31                     2
# 119389                     35                     29                     2
#
#         StaysInWeekNights  Adults  Children  ...        Agent      Company  \
# 0                       0       2       0.0  ...         NULL         NULL
# 1                       0       2       0.0  ...         NULL         NULL
# 2                       1       1       0.0  ...         NULL         NULL
# 3                       1       1       0.0  ...          304         NULL
# 4                       2       2       0.0  ...          240         NULL
# ...                   ...     ...       ...  ...          ...          ...
# 119385                  5       2       0.0  ...          394         NULL
# 119386                  5       3       0.0  ...            9         NULL
# 119387                  5       2       0.0  ...            9         NULL
# 119388                  5       2       0.0  ...           89         NULL
# 119389                  7       2       0.0  ...            9         NULL
#
#        DaysInWaitingList CustomerType     ADR  RequiredCarParkingSpaces  \
# 0                      0    Transient    0.00                         0
# 1                      0    Transient    0.00                         0
# 2                      0    Transient   75.00                         0
# 3                      0    Transient   75.00                         0
# 4                      0    Transient   98.00                         0
# ...                  ...          ...     ...                       ...
# 119385                 0    Transient   96.14                         0
# 119386                 0    Transient  225.43                         0
# 119387                 0    Transient  157.71                         0
# 119388                 0    Transient  104.40                         0
# 119389                 0    Transient  151.20                         0
#
#         TotalOfSpecialRequests  ReservationStatus ReservationStatusDate  \
# 0                            0          Check-Out            2015-07-01
# 1                            0          Check-Out            2015-07-01
# 2                            0          Check-Out            2015-07-02
# 3                            0          Check-Out            2015-07-02
# 4                            1          Check-Out            2015-07-03
# ...                        ...                ...                   ...
# 119385                       0          Check-Out            2017-09-06
# 119386                       2          Check-Out            2017-09-07
# 119387                       4          Check-Out            2017-09-07
# 119388                       0          Check-Out            2017-09-07
# 119389                       2          Check-Out            2017-09-07
#
#        HotelNumber
# 0               H1
# 1               H1
# 2               H1
# 3               H1
# 4               H1
# ...            ...
# 119385          H2
# 119386          H2
# 119387          H2
# 119388          H2
# 119389          H2
#
# [119390 rows x 32 columns]

# %% [markdown]
# # Generate UUIDs and Append to DataFrame

# %%
# Generate UUIDs for each row in the dataframe
data['UUID'] = [uuid.uuid4() for _ in range(len(data))]
data
# Out:
#         IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0                0       342             2015             July
# 1                0       737             2015             July
# 2                0         7             2015             July
# 3                0        13             2015             July
# 4                0        14             2015             July
# ...            ...       ...              ...              ...
# 119385           0        23             2017           August
# 119386           0       102             2017           August
# 119387           0        34             2017           August
# 119388           0       109             2017           August
# 119389           0       205             2017           August
#
#         ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                          27                      1                     0
# 1                          27                      1                     0
# 2                          27                      1                     0
# 3                          27                      1                     0
# 4                          27                      1                     0
# ...                       ...                    ...                   ...
# 119385                     35                     30                     2
# 119386                     35                     31                     2
# 119387                     35                     31                     2
# 119388                     35                     31                     2
# 119389                     35                     29                     2
#
#         StaysInWeekNights  Adults  Children  ...      Company  \
# 0                       0       2       0.0  ...         NULL
# 1                       0       2       0.0  ...         NULL
# 2                       1       1       0.0  ...         NULL
# 3                       1       1       0.0  ...         NULL
# 4                       2       2       0.0  ...         NULL
# ...                   ...     ...       ...  ...          ...
# 119385                  5       2       0.0  ...         NULL
# 119386                  5       3       0.0  ...         NULL
# 119387                  5       2       0.0  ...         NULL
# 119388                  5       2       0.0  ...         NULL
# 119389                  7       2       0.0  ...         NULL
#
#        DaysInWaitingList CustomerType     ADR RequiredCarParkingSpaces  \
# 0                      0    Transient    0.00                        0
# 1                      0    Transient    0.00                        0
# 2                      0    Transient   75.00                        0
# 3                      0    Transient   75.00                        0
# 4                      0    Transient   98.00                        0
# ...                  ...          ...     ...                      ...
# 119385                 0    Transient   96.14                        0
# 119386                 0    Transient  225.43                        0
# 119387                 0    Transient  157.71                        0
# 119388                 0    Transient  104.40                        0
# 119389                 0    Transient  151.20                        0
#
#         TotalOfSpecialRequests  ReservationStatus  ReservationStatusDate  \
# 0                            0          Check-Out             2015-07-01
# 1                            0          Check-Out             2015-07-01
# 2                            0          Check-Out             2015-07-02
# 3                            0          Check-Out             2015-07-02
# 4                            1          Check-Out             2015-07-03
# ...                        ...                ...                    ...
# 119385                       0          Check-Out             2017-09-06
# 119386                       2          Check-Out             2017-09-07
# 119387                       4          Check-Out             2017-09-07
# 119388                       0          Check-Out             2017-09-07
# 119389                       2          Check-Out             2017-09-07
#
#        HotelNumber                                  UUID
# 0               H1  9af79666-f290-45c5-868c-2f9601b8f98b
# 1               H1  81440274-e84e-4502-89f3-e01681d0672a
# 2               H1  60fe936c-f7ba-48d9-ac73-71c21e1b3978
# 3               H1  5b2aae61-1d0c-4314-b4c1-603595e43163
# 4               H1  e92881a3-faf8-402b-beff-64dad4707236
# ...            ...                                   ...
# 119385          H2  834c6a25-b7c4-4170-b8eb-3a00d830e397
# 119386          H2  1c6d7a7a-2ffe-4d85-b44a-717666d8d7cc
# 119387          H2  12af19d6-1594-4eef-bba8-643bc102cfea
# 119388          H2  1e62e04f-8fd3-4304-818c-07b37c4208e0
# 119389          H2  732b34e2-bbcf-4a43-b63b-73839173be8e
#
# [119390 rows x 33 columns]

# %% [markdown]
# ## Convert UUIDs to String Datatype

# %%
data['UUID'] = data['UUID'].astype(str)
data['UUID']
# Out:
# 0         9af79666-f290-45c5-868c-2f9601b8f98b
# 1         81440274-e84e-4502-89f3-e01681d0672a
# 2         60fe936c-f7ba-48d9-ac73-71c21e1b3978
# 3         5b2aae61-1d0c-4314-b4c1-603595e43163
# 4         e92881a3-faf8-402b-beff-64dad4707236
#                           ...
# 119385    834c6a25-b7c4-4170-b8eb-3a00d830e397
# 119386    1c6d7a7a-2ffe-4d85-b44a-717666d8d7cc
# 119387    12af19d6-1594-4eef-bba8-643bc102cfea
# 119388    1e62e04f-8fd3-4304-818c-07b37c4208e0
# 119389    732b34e2-bbcf-4a43-b63b-73839173be8e
# Name: UUID, Length: 119390, dtype: object

# %% [markdown]
# ## Set UUIDs as Index
#
# ---
#
# By setting the UUIDs as the dataframe's index, I maintain the unique identifier for each reservation and enable myself to perform joins with other datasets (such as engineered datasets later in the workflow0).
#
# ---

# %%
# data = data.set_index('UUID')
# data

# %% [markdown]
# # Save Results

# %%
data.to_parquet('../../data/source/full_data.parquet', compression = 'zstd')

# %% [markdown]
# ## Subset: Classification Data

# %%
data.columns.to_list()
# Out:
# ['IsCanceled',
#  'LeadTime',
#  'ArrivalDateYear',
#  'ArrivalDateMonth',
#  'ArrivalDateWeekNumber',
#  'ArrivalDateDayOfMonth',
#  'StaysInWeekendNights',
#  'StaysInWeekNights',
#  'Adults',
#  'Children',
#  'Babies',
#  'Meal',
#  'Country',
#  'MarketSegment',
#  'DistributionChannel',
#  'IsRepeatedGuest',
#  'PreviousCancellations',
#  'PreviousBookingsNotCanceled',
#  'ReservedRoomType',
#  'AssignedRoomType',
#  'BookingChanges',
#  'DepositType',
#  'Agent',
#  'Company',
#  'DaysInWaitingList',
#  'CustomerType',
#  'ADR',
#  'RequiredCarParkingSpaces',
#  'TotalOfSpecialRequests',
#  'ReservationStatus',
#  'ReservationStatusDate',
#  'HotelNumber',
#  'UUID']

# %%
classification_columns = [
'LeadTime',
 'ArrivalDateMonth',
 'ArrivalDateWeekNumber',
 'ArrivalDateDayOfMonth',
 'StaysInWeekendNights',
 'StaysInWeekNights',
 'Adults',
 'Children',
 'Babies',
 'Country',
 'MarketSegment',
 'DistributionChannel',
 'IsRepeatedGuest',
 'PreviousCancellations',
 'PreviousBookingsNotCanceled',
 'ReservedRoomType',
 'BookingChanges',
 'DepositType',
 'Agent',
 'Company',
 'DaysInWaitingList',
 'CustomerType',
 'ADR',
 'TotalOfSpecialRequests',
 'ReservationStatus',
 'HotelNumber']
data[classification_columns]
# Out:
#         LeadTime ArrivalDateMonth  ArrivalDateWeekNumber  \
# 0            342             July                     27
# 1            737             July                     27
# 2              7             July                     27
# 3             13             July                     27
# 4             14             July                     27
# ...          ...              ...                    ...
# 119385        23           August                     35
# 119386       102           August                     35
# 119387        34           August                     35
# 119388       109           August                     35
# 119389       205           August                     35
#
#         ArrivalDateDayOfMonth  StaysInWeekendNights  StaysInWeekNights  \
# 0                           1                     0                  0
# 1                           1                     0                  0
# 2                           1                     0                  1
# 3                           1                     0                  1
# 4                           1                     0                  2
# ...                       ...                   ...                ...
# 119385                     30                     2                  5
# 119386                     31                     2                  5
# 119387                     31                     2                  5
# 119388                     31                     2                  5
# 119389                     29                     2                  7
#
#         Adults  Children  Babies Country  ... BookingChanges      DepositType  \
# 0            2       0.0       0     PRT  ...              3  No Deposit
# 1            2       0.0       0     PRT  ...              4  No Deposit
# 2            1       0.0       0     GBR  ...              0  No Deposit
# 3            1       0.0       0     GBR  ...              0  No Deposit
# 4            2       0.0       0     GBR  ...              0  No Deposit
# ...        ...       ...     ...     ...  ...            ...              ...
# 119385       2       0.0       0     BEL  ...              0  No Deposit
# 119386       3       0.0       0     FRA  ...              0  No Deposit
# 119387       2       0.0       0     DEU  ...              0  No Deposit
# 119388       2       0.0       0     GBR  ...              0  No Deposit
# 119389       2       0.0       0     DEU  ...              0  No Deposit
#
#               Agent      Company  DaysInWaitingList CustomerType     ADR  \
# 0              NULL         NULL                  0    Transient    0.00
# 1              NULL         NULL                  0    Transient    0.00
# 2              NULL         NULL                  0    Transient   75.00
# 3               304         NULL                  0    Transient   75.00
# 4               240         NULL                  0    Transient   98.00
# ...             ...          ...                ...          ...     ...
# 119385          394         NULL                  0    Transient   96.14
# 119386            9         NULL                  0    Transient  225.43
# 119387            9         NULL                  0    Transient  157.71
# 119388           89         NULL                  0    Transient  104.40
# 119389            9         NULL                  0    Transient  151.20
#
#        TotalOfSpecialRequests ReservationStatus HotelNumber
# 0                           0         Check-Out          H1
# 1                           0         Check-Out          H1
# 2                           0         Check-Out          H1
# 3                           0         Check-Out          H1
# 4                           1         Check-Out          H1
# ...                       ...               ...         ...
# 119385                      0         Check-Out          H2
# 119386                      2         Check-Out          H2
# 119387                      4         Check-Out          H2
# 119388                      0         Check-Out          H2
# 119389                      2         Check-Out          H2
#
# [119390 rows x 26 columns]

# %%
data[classification_columns].to_parquet('../../data/source/classification_data.parquet', compression = 'zstd')
