# %% [markdown]
# # Forecasting Cancellations
#
# ---
#
#
# ---

# %% [markdown]
# # Imports

# %%
import json

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pmdarima as pmd
from pmdarima.arima import AutoARIMA, ndiffs, nsdiffs
from pmdarima.model_selection import train_test_split
from pmdarima.preprocessing import BoxCoxEndogTransformer, FourierFeaturizer
from pmdarima.pipeline import Pipeline
import statsmodels.tsa.api as tsa
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn import metrics

# %%
## Reading data and setting DT index
path = '../../data/3.3_data_exploded.feather'
data = pd.read_feather(path)
data = data.sort_values('Stay Date')
data = data.set_index('Stay Date')
data
# Out:
#             IsCanceled  Adults  Children  Babies       Meal Country  \
# Stay Date
# 2015-07-01           0       1       0.0       0  HB            PRT
# 2015-07-01           0       2       0.0       0  HB            PRT
# 2015-07-01           0       2       0.0       0  HB            PRT
# 2015-07-01           0       2       0.0       0  HB            PRT
# 2015-07-01           0       2       0.0       0  HB            PRT
# ...                ...     ...       ...     ...        ...     ...
# 2017-09-11           0       2       0.0       0  BB            IRL
# 2017-09-12           0       2       0.0       0  HB            DEU
# 2017-09-12           0       2       0.0       0  HB            GBR
# 2017-09-13           0       2       0.0       0  HB            DEU
# 2017-09-13           0       2       0.0       0  HB            GBR
#
#             MarketSegment DistributionChannel  IsRepeatedGuest  \
# Stay Date
# 2015-07-01  Offline TA/TO               TA/TO                0
# 2015-07-01  Offline TA/TO               TA/TO                0
# 2015-07-01  Offline TA/TO               TA/TO                0
# 2015-07-01  Offline TA/TO               TA/TO                0
# 2015-07-01  Offline TA/TO               TA/TO                0
# ...                   ...                 ...              ...
# 2017-09-11         Direct              Direct                0
# 2017-09-12  Offline TA/TO               TA/TO                0
# 2017-09-12  Offline TA/TO               TA/TO                0
# 2017-09-13  Offline TA/TO               TA/TO                0
# 2017-09-13  Offline TA/TO               TA/TO                0
#
#             PreviousCancellations  ...  ArrivalDate_DaysBeforeHoliday  \
# Stay Date                          ...
# 2015-07-01                      0  ...                             45
# 2015-07-01                      0  ...                             45
# 2015-07-01                      0  ...                             45
# 2015-07-01                      0  ...                             45
# 2015-07-01                      0  ...                             45
# ...                           ...  ...                            ...
# 2017-09-11                      0  ...                             37
# 2017-09-12                      0  ...                             35
# 2017-09-12                      0  ...                             35
# 2017-09-13                      0  ...                             35
# 2017-09-13                      0  ...                             35
#
#            ArrivalDate_DaysAfterHoliday DepartureDate_DaysBeforeHoliday  \
# Stay Date
# 2015-07-01                           21                              43
# 2015-07-01                           21                              43
# 2015-07-01                           21                              43
# 2015-07-01                           21                              43
# 2015-07-01                           21                              43
# ...                                 ...                             ...
# 2017-09-11                           14                              23
# 2017-09-12                           16                              21
# 2017-09-12                           16                              21
# 2017-09-13                           16                              21
# 2017-09-13                           16                              21
#
#             DepartureDate_DaysAfterHoliday BookingDate_DaysBeforeHoliday  \
# Stay Date
# 2015-07-01                              23                            51
# 2015-07-01                              23                            52
# 2015-07-01                              23                            52
# 2015-07-01                              23                            52
# 2015-07-01                              23                            52
# ...                                    ...                           ...
# 2017-09-11                              28                            67
# 2017-09-12                              30                            22
# 2017-09-12                              30                            72
# 2017-09-13                              30                            22
# 2017-09-13                              30                            72
#
#            BookingDate_DaysAfterHoliday ArrivalWeek  ArrivalDay  \
# Stay Date
# 2015-07-01                           15          27           3
# 2015-07-01                           63          27           3
# 2015-07-01                           63          27           3
# 2015-07-01                           63          27           3
# 2015-07-01                           63          27           3
# ...                                 ...         ...         ...
# 2017-09-11                           36          35           2
# 2017-09-12                           81          35           4
# 2017-09-12                           31          35           4
# 2017-09-13                           81          35           4
# 2017-09-13                           31          35           4
#
#            ArrivalDateDayName  ArrivalDateMonthName
# Stay Date
# 2015-07-01          Wednesday                  July
# 2015-07-01          Wednesday                  July
# 2015-07-01          Wednesday                  July
# 2015-07-01          Wednesday                  July
# 2015-07-01          Wednesday                  July
# ...                       ...                   ...
# 2017-09-11            Tuesday                August
# 2017-09-12           Thursday                August
# 2017-09-12           Thursday                August
# 2017-09-13           Thursday                August
# 2017-09-13           Thursday                August
#
# [409257 rows x 38 columns]

# %%
data['ReservationStatus'].value_counts()
# Out:
# ReservationStatus
# Check-Out    255040
# Canceled     149740
# No-Show        4477
# Name: count, dtype: int64

# %%
data.loc[:, 'ReservationStatus'] = np.where(data['ReservationStatus'] == 'No-Show', 'Canceled', data['ReservationStatus'])
data.loc[:, 'ReservationStatus']
# Out:
# Stay Date
# 2015-07-01    Check-Out
# 2015-07-01    Check-Out
# 2015-07-01    Check-Out
# 2015-07-01    Check-Out
# 2015-07-01    Check-Out
#                 ...
# 2017-09-11    Check-Out
# 2017-09-12    Check-Out
# 2017-09-12    Check-Out
# 2017-09-13    Check-Out
# 2017-09-13    Check-Out
# Name: ReservationStatus, Length: 409257, dtype: object

# %%
data['ReservationStatus'].value_counts(normalize=True).round(2)
# Out:
# ReservationStatus
# Check-Out    0.62
# Canceled     0.38
# Name: proportion, dtype: float64

# %%
res_statuses = pd.DataFrame(data['ReservationStatus'])
res_statuses
# Out:
#            ReservationStatus
# Stay Date
# 2015-07-01         Check-Out
# 2015-07-01         Check-Out
# 2015-07-01         Check-Out
# 2015-07-01         Check-Out
# 2015-07-01         Check-Out
# ...                      ...
# 2017-09-11         Check-Out
# 2017-09-12         Check-Out
# 2017-09-12         Check-Out
# 2017-09-13         Check-Out
# 2017-09-13         Check-Out
#
# [409257 rows x 1 columns]

# %%
## Group by date and reservation status
result = res_statuses.groupby(res_statuses.index).value_counts()
result_unstacked = result.unstack(fill_value=0)
result_unstacked
# Out:
# ReservationStatus  Canceled  Check-Out
# Stay Date
# 2015-07-01               19        101
# 2015-07-02               76        130
# 2015-07-03               85         94
# 2015-07-04               85        130
# 2015-07-05               77        134
# ...                     ...        ...
# 2017-09-09                2          7
# 2017-09-10                2          3
# 2017-09-11                0          3
# 2017-09-12                0          2
# 2017-09-13                0          2
#
# [806 rows x 2 columns]

# %%
result_unstacked.plot();
# Out:
# <Axes: xlabel='Stay Date'>
